# %% [markdown]
# # Predictive Maintenance for Fleet Vehicles
# ## Data Science Project
#
# This project builds a machine learning model to predict vehicle failures using sensor data.

# %% [markdown]
# ## Problem Statement
# Fleet vehicles experience unexpected failures. Goal is to predict failures proactively.

# %%
import sys
# !{sys.executable} -m pip install "numpy<2.0"
import sys
# !{sys.executable} -m pip install --force-reinstall pandas scikit-learn scipy matplotlib


import sys
# !{sys.executable} -m pip install pandas numpy scikit-learn matplotlib

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 83.9 MB/s  0:00:006m0:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 97.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 102.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 106.2 MB/s  0:00:00m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 129.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 93.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 130.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 71.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 156.4 MB/s  0:00:00
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2026.1.post1
#     Uninstalling pytz-2026.1.post1:
# ...

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('sample_vehicle_sensor_data.csv')
df.head()
# Out:
#   vehicle_id  engine_temp_c  vibration_mm_s  avg_rpm  error_code_count  \
# 0   VH-00001           95.4            5.03   2287.0                 1
# 1   VH-00002           84.7            5.55   3009.0                 0
# 2   VH-00003           99.0            2.41   2297.0                 2
# 3   VH-00004          100.5            4.12   2767.0                 2
# 4   VH-00005           77.4            3.89   2049.0                 2
#
#    battery_voltage
# 0            12.69
# 1            11.35
# 2            12.96
# 3            12.67
# 4            11.73

# %% [markdown]
# ## Simple Model

# %%
from sklearn.model_selection import train_test_split

X = df[['engine_temp_c','vibration_mm_s','avg_rpm','error_code_count','battery_voltage']]
y = np.random.randint(0,2,len(df))

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

model = RandomForestClassifier()
model.fit(X_train,y_train)

preds = model.predict(X_test)
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.38      0.55         8
#            1       0.29      1.00      0.44         2
#
#     accuracy                           0.50        10
#    macro avg       0.64      0.69      0.49        10
# weighted avg       0.86      0.50      0.53        10
